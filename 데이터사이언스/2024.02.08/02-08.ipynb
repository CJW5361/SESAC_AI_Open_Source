# %% [markdown]
# https://some.co.kr/
#
#
# https://brochure.konantech.com/
#
#
#
# http://tech.kobeta.com/wp-content/uploads/2021/01/30108.pdf
# - #1,2,3 시리즈 있음
# - http://tech.kobeta.com/wp-content/uploads/2021/02/30208.pdf
# - http://tech.kobeta.com/wp-content/uploads/2021/03/30307.pdf
#
#
# 필터버블 - 필터링 된 정보 안에 갇히는 현상

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# [[3,2,0,2],
#
#
#
# [1,2,3,0],                                          => 3행4열 -> 2차원
#
#
#
# [2,2,2,2]]
#
#
#
#
# ([:,0]-q[0])
#
#
#
#
# Q
#
#
#
#
# [[1],[5],[0],[0]]

# %% [markdown]
# ![image.png](attachment:image.png)
