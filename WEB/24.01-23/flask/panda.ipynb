# %%
import pandas as pd 
datas=pd.read_csv('data/data.csv')
datas.to_dict(orient='records')
# Out:
# [{'name': '반원', 'label': 60, 'point': 360, 'exp': 45000},
#  {'name': '반원2', 'label': 2, 'point': 20, 'exp': 200},
#  {'name': '반원3', 'label': 3, 'point': 30, 'exp': 300}]

# %%
import pandas as pd 
url='http://companyinfo.stock.naver.com/v1/company/c1010001.aspx?cmp_cd=005930'
datas=pd.read_html(url,encoding='utf-8')[12]
datas=datas.to_dict(orient="records")
datas
# Out:
# [{'제공처': 'KB',
#   '최종일자': '24/01/18',
#   '목표가': 95000,
#   '직전목표가': 95000,
#   '변동률(%)': 0.0,
#   '투자의견': 'BUY',
#   '직전투자의견': 'BUY'},
#  {'제공처': 'DB금융투자',
#   '최종일자': '24/01/16',
#   '목표가': 94000,
#   '직전목표가': 94000,
#   '변동률(%)': 0.0,
#   '투자의견': 'Buy',
#   '직전투자의견': 'Buy'},
#  {'제공처': '한화투자',
#   '최종일자': '24/01/16',
#   '목표가': 94000,
#   '직전목표가': 94000,
#   '변동률(%)': 0.0,
#   '투자의견': 'Buy',
#   '직전투자의견': 'Buy'},
#  {'제공처': '현대차',
#   '최종일자': '24/01/16',
#   '목표가': 89000,
#   '직전목표가': 89000,
#   '변동률(%)': 0.0,
#   '투자의견': 'BUY',
#   '직전투자의견': 'BUY'},
#  {'제공처': 'IBK투자',
#   '최종일자': '24/01/16',
#   '목표가': 90000,
#   '직전목표가': 90000,
#   '변동률(%)': 0.0,
#   '투자의견': '매수',
#   '직전투자의견': '매수'},
#  {'제공처': '메리츠',
#   '최종일자': '24/01/15',
#   '목표가': 95000,
#   '직전목표가': 95000,
#   '변동률(%)': 0.0,
#   '투자의견': 'Buy',
#   '직전투자의견': 'Buy'},
#  {'제공처': '하이투자',
#   '최종일자': '24/01/10',
#   '목표가': 87000,
#   '직전목표가': 83000,
#   '변동률(%)': 4.82,
#   '투자의견': 'Buy',
#   '직전투자의견': 'Buy'},
# ...

# %%
import pandas as pd 
import html5lib
import requests
from bs4 import BeautifulSoup as bs

url='http://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList?serviceKey=wKXVoZD3JTnajz7I2NG5STcdGGkG%2B9wYeT0RnnZnbFzOnVpgdv5oysBgCVdD3HomSPkHinfymX9QAYSjj2Vc1Q%3D%3D&pageNo=1&numOfRows=152&dataType=XML&dataCd=ASOS&dateCd=DAY&startDt=20100101&endDt=20100601&stnIds=108'
xml=requests.get(url,verify=False)

soup=bs(xml.text,'html.parser')
items=soup.find_all('item')
data=[]
for item in items:
    data.append({
        '지점명': item.find('stnnm').text if item.find('stnnm') else None,
    })
data
# Out:
# [{'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
#  {'지점명': '서울'},
# ...
