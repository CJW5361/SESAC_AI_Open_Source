# %% [markdown]
# ### DISTINCT 중복제거 (SQL)
#
# 우리고객 데이터 나라별 데이터로 뽑아주세요
#
#
#
# -> 나라별 중복데이터를 제거해서 뽑아야함
#
#
#
# SELECT DISTINCT Country FROM Customers

# %% [markdown]
# ```
# SELECT DISTINCT country, city
# FROM Customers
# WHERE city LIKE '%Seattle%'
# );
# ```
#
#
# -> Seattle인거 뽑아 내기
#
#
#
# '%B' -> B로 끝나는
#
#
#
# 'B%' -> B로 시작하는

# %% [markdown]
# ```
# SELECT * FROM ( SELECT DISTINCT country,city FROM customers) AS a
# ```
# - (AS 생략가능)
# a라는 테이블로 만들기 가능
# - 별칭 (AS) 는 생략가능하면 프로그램에 따라서 [  ] 또는 ""안에 기술 가능

# %% [markdown]
# -----

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# VIEW 테이블
# - 일반적으로 join 한 테이블 등록시켜 놓음
#   - 또는 만들어 놓은 구문 의 결과(하위 테이블 대신)
# - 일반 user는 테이블 생성 못하지만
# - 상황에 따라 view는 생성 할 수 있다.

# %% [markdown]
# ---------

# %% [markdown]
# ### PRIMARY KEY ->개체 무결성[기본키]-중복X, 중요!
# 외래키-> 참조 무결성

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -------

# %% [markdown]
# select 필드명
#
#
#
# from 테이블
#
#
# where 조건절
#
#
# group by 묶음
#
#
#
# having 그룹바이단위로 조건
#
#
#
# order by 순서대로 (asc기본) DESC
#
#
#    ```
# group by 나이
#      having sum(나이)>300
#    ```

# %% [markdown]
# ### 조건에 맞는 사용자와 총 거래금액 조회하기
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-5.png](attachment:image-5.png)
# - ![image.png](attachment:image.png)
# - ![image-2.png](attachment:image-2.png)
# - ![image-3.png](attachment:image-3.png)
# - ![image-4.png](attachment:image-4.png)
