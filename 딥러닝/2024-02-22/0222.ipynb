# %% [markdown]
# 오늘강의는 파이토치 기본부터 강의합니다.
# - => 구글검색 텐서플로우, 파이토치, 케라스 딥러닝 프레임워크' (2020년을 기준으로 서1과 텐서2가 나뉘게 됨, 코드가 다름)
# - 2020년전까지는 난이도 (텐서1가장어려움, 파이토치, 케라스 가장쉬움)
# - 2020년이후 (파이토치 가장어려움, 텐서2의 케라스API가 쉬움)
# - 2020년도에 텐서플로우가 케라스(고수준AP)를
# • 파이토치는 딥러닝 함수식을 지원하는 모듈이며 메타(페이스북)에서 만든 모듈임
# •> 2015년도에 구글 텐서플로우1 이 저수준 AP(최소한의 모듈만제공)를 제공함 일반사용자는 2017년도부터 모듈사용함
# - (사용자가 마음껏 프로그래밍 할수 있으나, 프로그래밍의 어려움과 GPU텐서와 CPU텐서를 처음부터 세팅하여서 작업하여야 하는 단점이 있어, 상황에 따른 GPU,CPU선택과 프로그램을 좀더 쉽게 하고자 하는 이슈로 파이토치 모듈이 생성됨)
# 파이토치:텐서1의 난해함과 GPU,CPU를 선택하지 못하고 처음부터 세팅된 GPU텐서, CPU서만 사용할수 있다는 단점때문에 프로그램에서 Cpu와
# gpu device 선택하면서 작업할수 있는 torch 가 많은 연구자들이 사용하게 됨
# - 또한 텐서1보다 조금은 쉬운 모듈화가 제공되어 있어 프로그램하기 쉬우며 텐서1에서는 텐서라는 별도의 자료형이 있으나, torch에서는 numpy 자료형을 곧바로 사용할수 있는 장점이 있음
# • 케라스: 고수준 AP(블랙박스 모델제공: 현재 텐서플로2와 같은 모듈), 2023년도에 keras Core3.0이 출시됨(텐서와 별개임)
# - 상관없이 케라스 모듈을 호출해서 사용했었음.
# - 케라스는 텐서플로우 12 부터 텐서에 통합된 모듈임. 텐서1에서는 상황에 따라 텐서플로우에서 케라스 함수를 호출해서 사용하거나, 또는 텐서플로우와 텐서플로우2는 이러한 케라스를 탑재해서 사용함

# %% [markdown]
# 구글검색 텐서플로우, 파이토치, 케라스 딥러닝 프레임워크'
# - ![image.png](attachment:image.png)
# - https://hongong.hanbit.co.kr/%EB%94%A5%EB%9F%AC%EB%8B%9D-%ED%94%84%EB%A0%88%EC%9E%84%EC%9B%8C%ED%81%AC-%EB%B9%84%EA%B5%90-%ED%85%90%EC%84%9C%ED%94%8C%EB%A1%9C-%EC%BC%80%EB%9D%BC%EC%8A%A4-%ED%8C%8C%EC%9D%B4%ED%86%A0%EC%B9%98/
# - https://happy-jihye.github.io/gan/gan-21/#2-application--change-facial-expression--pose

# %% [markdown]
# ## Torch
# - 홈페이지의 tutorial과 documents 잘보기
# - https://tutorials.pytorch.kr/beginner/blitz/cifar10_tutorial.html
#   - https://wegonnamakeit.tistory.com/48
#
# transform=transform
# - https://wikidocs.net/157285 (transform 종류)
# - numworker= https://jybaek.tistory.com/799 ( cpu gpu 연산 관련)
#
# torch - plot 충돌
# - https://life-is-potatoo.tistory.com/100

# %% [markdown]
# 파이토치 cnn 모델코드
# 1. 입력자료 32,32,3
# 2.출력 카테고리는 10개
#
# user
# w,b값 출력
# ,자세하게 설명
# 가중치가 적용된 시각화
# first_batch[0]에 filters를 적용한 시각화
# 흰색영역의 빈도수를 히스토그램
# 적정한 w값인
