# %% [markdown]
# ### 테스트 본거 문제풀이

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# w갱신을 많이 하려면 --> 훈련에만 잘맞는 과적합이 일어날 확률
# - 1.레이어의 갯수가 많음
# - 2.Dense의 갯수가 많음
# - 3.에포크가 많을 수록
# - 4.배치크기가 작을수록

# %% [markdown]
# 데이터 증강 대신 사용할 수 있는 방법
# - 머신러닝은 증강 X
# - 딥러닝중에서도 의료분야등 특수분야는 증강x(비정형 변형x)
# - Kfold 교차검증

# %% [markdown]
# ### 데이터 불균형

# %% [markdown]
# https://bommbom.tistory.com/entry/%EB%B6%88%EA%B7%A0%ED%98%95-%EB%8D%B0%EC%9D%B4%ED%84%B0Data-Imbalance-%EC%B2%98%EB%A6%AC-%EC%98%A4%EB%B2%84-%EC%83%98%ED%94%8C%EB%A7%81Over-Sampling-ResamplingSMOTEBorderline

# %% [markdown]
# https://www.cognex.com/ko-kr/blogs/deep-learning/research/anomaly-detection-overview-1-introduction-anomaly-detection

# %% [markdown]
# https://www.lotis.or.kr/news/5055(cctv 이상상황 검출 불균형)

# %% [markdown]
# 3채널의 8*8 5장있다 -> 2장씩나눴다(batch_size=2)
# 12 1
# 34 2    epoch 1
# 5  3
#
# 3*5= 15번 갱신
